# %% [markdown]
# <a href="https://colab.research.google.com/github/huy20146177/baitapAI/blob/main/btvn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 25.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=0e6c76a1a3dcc5d779178c216eef99c33685e1d7de42ee3fe97a99c3c08944b7
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
# khai bao cac bien membership 
taste = ctrl.Antecedent(np.arange(0,3.2,0.5),'taste')
environment = ctrl.Antecedent(np.arange(0,3.5,0.5),'environment')
budget = ctrl.Antecedent(np.arange(0,9.3,0.5),'budget')
review = ctrl.Antecedent(np.arange(0,5.3,0.25),'review')
location = ctrl.Antecedent(np.arange(0,3.2,0.5),'location')
output_ans = ctrl.Consequent(np.arange(0,15.5,0.5),'output_ans')

# Khai bao cac gia tri danh gia
taste['low'] = fuzz.trimf(taste.universe,[0,0.6,1])
taste['medium'] = fuzz.trimf(taste.universe,[0.5,1.7,2.5])
taste['high'] = fuzz.trimf(taste.universe,[2,2.7,3])

environment['casual'] = fuzz.trimf(environment.universe,[0,0,1.7])
environment['formal'] = fuzz.trimf(environment.universe,[0,1.7,3])
environment['luxurious'] = fuzz.trimf(environment.universe,[1.7,3,3])

budget['less preference'] = fuzz.trimf(budget.universe,[0,1.7,3])
budget['preference'] = fuzz.trimf(budget.universe,[2,4.7,7])
budget['more preference'] = fuzz.trimf(budget.universe,[6,7.7,9])

review['less preference'] = fuzz.trimf(review.universe,[0,0,2])
review['preference'] = fuzz.trimf(review.universe,[1,2.3,3.5])
review['more preference'] = fuzz.trimf(review.universe,[3,4.1,5])

location['close'] = fuzz.trimf(location.universe,[0,0,1])
location['near'] = fuzz.trimf(location.universe,[0.5,1.7,2.5])
location['far'] = fuzz.trimf(location.universe,[2,2.7,3])


output_ans['level_1'] = fuzz.trimf(output_ans.universe,[0,1.7,3])
output_ans['level_2'] = fuzz.trimf(output_ans.universe,[3,4.3,6])
output_ans['level_3'] = fuzz.trimf(output_ans.universe,[6,7.7,9])
output_ans['level_4'] = fuzz.trimf(output_ans.universe,[9,10.2,12])
output_ans['level_5'] = fuzz.trimf(output_ans.universe,[12,13.7,15])

     

taste.view()
environment.view()
budget.view()
review.view()
location.view()
output_ans.view()

# %%
####taste low and environment casual####
rule_1 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['less preference']&location['close'],output_ans['level_1'])
rule_2 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['less preference']&location['close'],output_ans['level_1'])
rule_3 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_4 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['preference']&location['close'],output_ans['level_1'])
rule_5 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['preference']&location['close'],output_ans['level_1'])
rule_6 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['preference']&location['close'],output_ans['level_2'])
rule_7 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['more preference']&location['close'],output_ans['level_1'])
rule_8 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['more preference']&location['close'],output_ans['level_1'])
rule_9 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['more preference']&location['close'],output_ans['level_2'])

rule_10 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['less preference']&location['near'],output_ans['level_1'])
rule_11 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['less preference']&location['near'],output_ans['level_1'])
rule_12 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['less preference']&location['near'],output_ans['level_1'])
rule_13 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['preference']&location['near'],output_ans['level_1'])
rule_14 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['preference']&location['near'],output_ans['level_1'])
rule_15 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['preference']&location['near'],output_ans['level_2'])
rule_16 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_17 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_18 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['more preference']&location['near'],output_ans['level_2'])

rule_19 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['less preference']&location['far'],output_ans['level_1'])
rule_20 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['less preference']&location['far'],output_ans['level_1'])
rule_21 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_22 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['preference']&location['far'],output_ans['level_1'])
rule_23 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['preference']&location['far'],output_ans['level_1'])
rule_24 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['preference']&location['far'],output_ans['level_2'])
rule_25 = ctrl.Rule(taste['low']&environment['casual']&budget['less preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_26 = ctrl.Rule(taste['low']&environment['casual']&budget['preference']&review['more preference']&location['far'],output_ans['level_1'])
rule_27 = ctrl.Rule(taste['low']&environment['casual']&budget['more preference']&review['more preference']&location['far'],output_ans['level_2'])

#### taste low and environment formal####
rule_28 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_29 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_30 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_31 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['preference']&location['close'],output_ans['level_1'])
rule_32 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['preference']&location['close'],output_ans['level_2'])
rule_33 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['preference']&location['close'],output_ans['level_2'])
rule_34 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['more preference']&location['close'],output_ans['level_1'])
rule_35 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['more preference']&location['close'],output_ans['level_1'])
rule_36 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['more preference']&location['close'],output_ans['level_2'])

rule_37 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['less preference']&location['near'],output_ans['level_1'])
rule_38 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_39 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_40 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['preference']&location['near'],output_ans['level_1'])
rule_41 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['preference']&location['near'],output_ans['level_2'])
rule_42 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['preference']&location['near'],output_ans['level_2'])
rule_43 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['more preference']&location['near'],output_ans['level_1'])
rule_44 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_45 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['more preference']&location['near'],output_ans['level_2'])

rule_46 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['less preference']&location['far'],output_ans['level_1'])
rule_47 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_48 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_49 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['preference']&location['far'],output_ans['level_1'])
rule_50 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['preference']&location['far'],output_ans['level_2'])
rule_51 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['preference']&location['far'],output_ans['level_2'])
rule_52 = ctrl.Rule(taste['low']&environment['formal']&budget['less preference']&review['more preference']&location['far'],output_ans['level_1'])
rule_53 = ctrl.Rule(taste['low']&environment['formal']&budget['preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_54 = ctrl.Rule(taste['low']&environment['formal']&budget['more preference']&review['more preference']&location['far'],output_ans['level_2'])

#### taste low and environment formal####

rule_55 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_56 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['less preference']&location['close'],output_ans['level_1'])
rule_57 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_58 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['preference']&location['close'],output_ans['level_2'])
rule_59 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['preference']&location['close'],output_ans['level_2'])
rule_60 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['preference']&location['close'],output_ans['level_3'])
rule_61 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['more preference']&location['close'],output_ans['level_3'])
rule_62 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['more preference']&location['close'],output_ans['level_2'])
rule_63 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['more preference']&location['close'],output_ans['level_3'])

rule_64 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_65 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_66 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_67 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['preference']&location['near'],output_ans['level_1'])
rule_68 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['preference']&location['near'],output_ans['level_2'])
rule_69 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['preference']&location['near'],output_ans['level_3'])
rule_70 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['more preference']&location['near'],output_ans['level_1'])
rule_71 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['more preference']&location['near'],output_ans['level_3'])
rule_72 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['more preference']&location['near'],output_ans['level_1'])

rule_73 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['less preference']&location['far'],output_ans['level_1'])
rule_74 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_75 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_76 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['preference']&location['far'],output_ans['level_1'])
rule_77 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['preference']&location['far'],output_ans['level_2'])
rule_78 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['preference']&location['far'],output_ans['level_3'])
rule_79 = ctrl.Rule(taste['low']&environment['luxurious']&budget['less preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_80 = ctrl.Rule(taste['low']&environment['luxurious']&budget['preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_81 = ctrl.Rule(taste['low']&environment['luxurious']&budget['more preference']&review['more preference']&location['far'],output_ans['level_3'])

###Taste medium###
rule_82 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_83 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_84 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_85 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['preference']&location['close'],output_ans['level_3'])
rule_86 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['preference']&location['close'],output_ans['level_2'])
rule_87 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['preference']&location['close'],output_ans['level_3'])
rule_88 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['more preference']&location['close'],output_ans['level_1'])
rule_89 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['more preference']&location['close'],output_ans['level_2'])
rule_90 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['more preference']&location['close'],output_ans['level_3'])

rule_91 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_92 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_93 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_94 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['preference']&location['near'],output_ans['level_2'])
rule_95 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['preference']&location['near'],output_ans['level_2'])
rule_96 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['preference']&location['near'],output_ans['level_3'])
rule_97 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_98 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_99 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['more preference']&location['near'],output_ans['level_3'])

rule_100 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_101 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_102 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_103 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['preference']&location['far'],output_ans['level_3'])
rule_104 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['preference']&location['far'],output_ans['level_2'])
rule_105 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['preference']&location['far'],output_ans['level_3'])
rule_106 = ctrl.Rule(taste['medium']&environment['casual']&budget['less preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_107 = ctrl.Rule(taste['medium']&environment['casual']&budget['preference']&review['more preference']&location['far'],output_ans['level_2'])
rule_108 = ctrl.Rule(taste['medium']&environment['casual']&budget['more preference']&review['more preference']&location['far'],output_ans['level_1'])

#### taste medium and environment formal####
rule_109 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_110 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_111 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_112 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['preference']&location['close'],output_ans['level_2'])
rule_113 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['preference']&location['close'],output_ans['level_3'])
rule_114 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['preference']&location['close'],output_ans['level_3'])
rule_115 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['more preference']&location['close'],output_ans['level_2'])
rule_116 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['more preference']&location['close'],output_ans['level_3'])
rule_117 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['more preference']&location['close'],output_ans['level_3'])

rule_118 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_119 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_120 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_121 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['preference']&location['near'],output_ans['level_2'])
rule_122 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['preference']&location['near'],output_ans['level_3'])
rule_123 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['preference']&location['near'],output_ans['level_3'])
rule_124 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_125 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['more preference']&location['near'],output_ans['level_3'])
rule_126 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['more preference']&location['near'],output_ans['level_3'])

rule_127 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['less preference']&location['far'],output_ans['level_2'])
rule_128 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_129 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_130 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['preference']&location['far'],output_ans['level_2'])
rule_131 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['preference']&location['far'],output_ans['level_3'])
rule_132 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['preference']&location['far'],output_ans['level_3'])
rule_133 = ctrl.Rule(taste['medium']&environment['formal']&budget['less preference']&review['more preference']&location['far'],output_ans['level_1'])
rule_134 = ctrl.Rule(taste['medium']&environment['formal']&budget['preference']&review['more preference']&location['far'],output_ans['level_3'])
rule_135 = ctrl.Rule(taste['medium']&environment['formal']&budget['more preference']&review['more preference']&location['far'],output_ans['level_2'])

#### taste medium and environment luxurious####

rule_136 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['less preference']&location['close'],output_ans['level_2'])
rule_137 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_138 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_139 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['preference']&location['close'],output_ans['level_2'])
rule_140 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['preference']&location['close'],output_ans['level_3'])
rule_141 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['preference']&location['close'],output_ans['level_3'])
rule_142 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['more preference']&location['close'],output_ans['level_2'])
rule_143 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['more preference']&location['close'],output_ans['level_3'])
rule_144 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['more preference']&location['close'],output_ans['level_3'])

rule_145 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['less preference']&location['near'],output_ans['level_2'])
rule_146 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_147 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_148 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['preference']&location['near'],output_ans['level_2'])
rule_149 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['preference']&location['near'],output_ans['level_3'])
rule_150 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['preference']&location['near'],output_ans['level_3'])
rule_151 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['more preference']&location['near'],output_ans['level_2'])
rule_152 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['more preference']&location['near'],output_ans['level_3'])
rule_153 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['more preference']&location['near'],output_ans['level_3'])

rule_154 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_155 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_156 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_157 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['preference']&location['far'],output_ans['level_3'])
rule_158 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['preference']&location['far'],output_ans['level_3'])
rule_159 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['preference']&location['far'],output_ans['level_3'])
rule_160 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['less preference']&review['more preference']&location['far'],output_ans['level_3'])
rule_161 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['preference']&review['more preference']&location['far'],output_ans['level_3'])
rule_162 = ctrl.Rule(taste['medium']&environment['luxurious']&budget['more preference']&review['more preference']&location['far'],output_ans['level_3'])

###Taste high###
rule_163 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['less preference']&location['close'],output_ans['level_3'])
rule_164 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_165 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_166 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['preference']&location['close'],output_ans['level_3'])
rule_167 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['preference']&location['close'],output_ans['level_3'])
rule_168 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['preference']&location['close'],output_ans['level_4'])
rule_169 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['more preference']&location['close'],output_ans['level_4'])
rule_170 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['more preference']&location['close'],output_ans['level_3'])
rule_171 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['more preference']&location['close'],output_ans['level_4'])

rule_172 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_173 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_174 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['less preference']&location['near'],output_ans['level_3'])
rule_175 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['preference']&location['near'],output_ans['level_4'])
rule_176 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['preference']&location['near'],output_ans['level_3'])
rule_177 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['preference']&location['near'],output_ans['level_4'])
rule_178 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['more preference']&location['near'],output_ans['level_3'])
rule_179 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['more preference']&location['near'],output_ans['level_3'])
rule_180 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['more preference']&location['near'],output_ans['level_4'])

rule_181 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['less preference']&location['far'],output_ans['level_3'])
rule_182 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_183 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_184 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['preference']&location['far'],output_ans['level_3'])
rule_185 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['preference']&location['far'],output_ans['level_4'])
rule_186 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['preference']&location['far'],output_ans['level_4'])
rule_187 = ctrl.Rule(taste['high']&environment['casual']&budget['less preference']&review['more preference']&location['far'],output_ans['level_3'])
rule_188 = ctrl.Rule(taste['high']&environment['casual']&budget['preference']&review['more preference']&location['far'],output_ans['level_4'])
rule_189 = ctrl.Rule(taste['high']&environment['casual']&budget['more preference']&review['more preference']&location['far'],output_ans['level_4'])

#### taste high and environment formal####
rule_190 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_191 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_192 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_193 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['preference']&location['close'],output_ans['level_4'])
rule_194 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['preference']&location['close'],output_ans['level_4'])
rule_195 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['preference']&location['close'],output_ans['level_4'])
rule_196 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['more preference']&location['close'],output_ans['level_4'])
rule_197 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['more preference']&location['close'],output_ans['level_4'])
rule_198 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['more preference']&location['close'],output_ans['level_4'])

rule_199 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_200 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_201 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_202 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['preference']&location['near'],output_ans['level_4'])
rule_203 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['preference']&location['near'],output_ans['level_4'])
rule_204 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['preference']&location['near'],output_ans['level_4'])
rule_205 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['more preference']&location['near'],output_ans['level_4'])
rule_206 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['more preference']&location['near'],output_ans['level_4'])
rule_207 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['more preference']&location['near'],output_ans['level_4'])

rule_208 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_209 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_210 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_211 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['preference']&location['far'],output_ans['level_4'])
rule_212 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['preference']&location['far'],output_ans['level_4'])
rule_213 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['preference']&location['far'],output_ans['level_4'])
rule_214 = ctrl.Rule(taste['high']&environment['formal']&budget['less preference']&review['more preference']&location['far'],output_ans['level_4'])
rule_215 = ctrl.Rule(taste['high']&environment['formal']&budget['preference']&review['more preference']&location['far'],output_ans['level_4'])
rule_216 = ctrl.Rule(taste['high']&environment['formal']&budget['more preference']&review['more preference']&location['far'],output_ans['level_4'])

#### taste high and environment luxurious####

rule_217 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['less preference']&location['close'],output_ans['level_4'])
rule_218 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['less preference']&location['close'],output_ans['level_5'])
rule_219 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['less preference']&location['close'],output_ans['level_5'])
rule_220 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['preference']&location['close'],output_ans['level_4'])
rule_221 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['preference']&location['close'],output_ans['level_5'])
rule_222 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['preference']&location['close'],output_ans['level_4'])
rule_223 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['more preference']&location['close'],output_ans['level_5'])
rule_224 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['more preference']&location['close'],output_ans['level_5'])
rule_225 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['more preference']&location['close'],output_ans['level_5'])

rule_226 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_227 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_228 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['less preference']&location['near'],output_ans['level_4'])
rule_229 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['preference']&location['near'],output_ans['level_4'])
rule_230 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['preference']&location['near'],output_ans['level_4'])
rule_231 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['preference']&location['near'],output_ans['level_5'])
rule_232 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['more preference']&location['near'],output_ans['level_5'])
rule_233 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['more preference']&location['near'],output_ans['level_4'])
rule_234 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['more preference']&location['near'],output_ans['level_5'])

rule_235 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_236 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['less preference']&location['far'],output_ans['level_4'])
rule_237 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['less preference']&location['far'],output_ans['level_5'])
rule_238 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['preference']&location['far'],output_ans['level_4'])
rule_239 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['preference']&location['far'],output_ans['level_4'])
rule_240 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['preference']&location['far'],output_ans['level_5'])
rule_241 = ctrl.Rule(taste['high']&environment['luxurious']&budget['less preference']&review['more preference']&location['far'],output_ans['level_4'])
rule_242 = ctrl.Rule(taste['high']&environment['luxurious']&budget['preference']&review['more preference']&location['far'],output_ans['level_4'])
rule_243 = ctrl.Rule(taste['high']&environment['luxurious']&budget['more preference']&review['more preference']&location['far'],output_ans['level_5'])

output_ctrl = ctrl.ControlSystem([rule_1,rule_2,rule_3,rule_4,rule_5,rule_6,rule_7,rule_8,rule_9,rule_10,rule_11,rule_12,rule_13,rule_14,rule_15,rule_16,rule_17,rule_18,rule_19,rule_20,rule_21,rule_22,rule_23,rule_24,rule_25,rule_26,rule_27,rule_28,rule_29,rule_30,rule_31,rule_32,rule_33,rule_34,rule_35,rule_36,rule_37,rule_38,rule_39,rule_40,rule_41,rule_42,rule_43,rule_44,rule_45,rule_46,rule_47,rule_48,rule_49,rule_50,rule_51,rule_52,rule_53,rule_54,rule_55,rule_56,rule_57,rule_58,rule_59,rule_60,rule_61,rule_62,rule_63,rule_64,rule_65,rule_66,rule_67,rule_68,rule_69,rule_70,rule_71,rule_72,rule_73,rule_74,rule_75,rule_76,rule_77,rule_78,rule_79,rule_80,rule_81,rule_82,rule_83,rule_84,rule_85,rule_86,rule_87,rule_88,rule_89,rule_90,rule_91,rule_92,rule_93,rule_94,rule_95,rule_96,rule_97,rule_98,rule_99,rule_100,rule_101,rule_102,rule_103,rule_104,rule_105,rule_106,rule_107,rule_108,rule_109,rule_110,rule_111,rule_112,rule_113,rule_114,rule_115,rule_116,rule_117,rule_118,rule_119,rule_120,rule_121,rule_122,rule_123,rule_124,rule_125,rule_126,rule_127,rule_128,rule_129,rule_130,rule_131,rule_132,rule_133,rule_134,rule_135,rule_136,rule_137,rule_138,rule_139,rule_140,rule_141,rule_142,rule_143,rule_144,rule_145,rule_146,rule_147,rule_148,rule_149,rule_150,rule_151,rule_152,rule_153,rule_154,rule_155,rule_156,rule_157,rule_158,rule_159,rule_160,rule_161,rule_162,rule_163,rule_164,rule_165,rule_166,rule_167,rule_168,rule_169,rule_170,rule_171,rule_172,rule_173,rule_174,rule_175,rule_176,rule_177,rule_178,rule_179,rule_180,rule_181,rule_182,rule_183,rule_184,rule_185,rule_186,rule_187,rule_188,rule_189,rule_190,rule_191,rule_192,rule_193,rule_194,rule_195,rule_196,rule_197,rule_198,rule_199,rule_200,rule_201,rule_202,rule_203,rule_204,rule_205,rule_206,rule_207,rule_208,rule_209,rule_210,rule_211,rule_212,rule_213,rule_214,rule_215,rule_216,rule_217,rule_218,rule_219,rule_220,rule_221,rule_222,rule_223,rule_224,rule_225,rule_226,rule_227,rule_228,rule_229,rule_230,rule_231,rule_232,rule_233,rule_234,rule_235,rule_236,rule_237,rule_238,rule_239,rule_240,rule_241,rule_242,rule_243])
outputing = ctrl.ControlSystemSimulation(output_ctrl)
outputing.input['taste'] = 2.7
outputing.input['environment'] = 1.3
outputing.input['budget'] = 5.7
outputing.input['review'] = 3.4
outputing.input['location'] = 1.7
outputing.compute()
print(outputing.output['output_ans'])
output_ans.view(sim = outputing)
# Out:
# 9.246477401896199
